# %% [markdown]
# #DATA SCIENCE INTERN @BHARAT INTERN
# ###Project by : Ajit Yadav
# #TASK 1 : STOCK PREDICTION
# ###PURPOSE : TO PREDICT THE STOCK PRICE OF A COMPANY USING LSTM (Long Short-Term Memory).
# ###ABOUT DATASET
# ####Google Stock Prediction

# %% [markdown]
# ##Content
#
# #####This dataset contains historical data of Google's stock prices and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.
# <br>
#
# #####The columns in the dataset are as follows: <br>
#
# <br>
#
# ###### 1. **Symbol** : The name of the company, which is GOOG in this case.
# ###### 2. **Date** : The year and date of the stock data.
# ###### 3. **Close** : The closing price of Google's stock on a particular day.
# ###### 4. **High** : The highest value reached by Google's stock on the given day.
# ###### 5. **Low** : The lowest value reached by Google's stock on the given day.
# ###### 6. **Open** : The opening value of Google's stock on the given day.
# ###### 7. **Volume** : The trading volume of Google's stock on the given day, i.e., the number of shares traded.
# ###### 8. **adjClose** : The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
# ###### 9. **adjHigh** : The adjusted highest value reached by Google's stock on the given day.
# ###### 10. **adjLow** : The adjusted lowest value reached by Google's stock on the given day.
# ###### 11. **adjOpen** : The adjusted opening value of Google's stock on the given day.
# ###### 12. **adjVolume** : The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
# ###### 13. **divCash** : The amount of cash dividend paid out to shareholders on the given day.
# ###### 14. **splitFactor** : The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.
#
# <br>
#
# ###### The dataset is available at Kaggle : https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction

# %% [markdown]
# ##STEPS INVOLVED :
# ####1. IMPORTING LIBRARIES AND DATA TO BE USED
# ####2. GATHERING INSIGHTS
# ####3. DATA PRE-PROCESSING
# ####4. CREATING LSTM MODEL
# ####5. VISUALIZING ACTUAL VS PREDICTED DATA
# ####6. PREDICTING UPCOMING 15 DAYS

# %% [markdown]
# ##STEP 1 : IMPORTING NECESSARY LIBRARIES AND TEH DATA TO BE USED

# %%
#Importing Necessary libraries to be used

import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/drive/MyDrive/Bharat_Intern/GOOG.csv') # importing the data
df.head(5) # fetching first 5 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ##STEP 2 : GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# #####Inference : There are no null values in the dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype for real time and dynamic analysis
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index

fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# ##STEP 3 : DATA PRE-PROCESSING

# %%
# Normalizing all the values of all columns using MinMaxScaler function ()
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %% [markdown]
# #####Inference: Transform features by scaling each feature to a given range [0,1], as there are no negative values.

# %%
# Splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ##STEP 4 : CREATING A LSTM MODEL

# %%
# Imported Sequential from keras.models
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers

model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 50, 50)            10600
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fitting the model by iterating the dataset over 100 times(100 epochs)

model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 4s 39ms/step - loss: 0.0078 - mean_absolute_error: 0.0615 - val_loss: 0.0098 - val_mean_absolute_error: 0.0771
# Epoch 2/100
# 28/28 [==============================] - 0s 9ms/step - loss: 7.7195e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0066 - val_mean_absolute_error: 0.0664
# Epoch 3/100
# 28/28 [==============================] - 0s 10ms/step - loss: 4.4256e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0038 - val_mean_absolute_error: 0.0486
# Epoch 4/100
# 28/28 [==============================] - 0s 13ms/step - loss: 4.1784e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0032 - val_mean_absolute_error: 0.0432
# Epoch 5/100
# 28/28 [==============================] - 0s 14ms/step - loss: 4.0803e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0047 - val_mean_absolute_error: 0.0545
# Epoch 6/100
# 28/28 [==============================] - 0s 14ms/step - loss: 4.2271e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0036 - val_mean_absolute_error: 0.0461
# Epoch 7/100
# 28/28 [==============================] - 0s 14ms/step - loss: 4.0480e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0050 - val_mean_absolute_error: 0.0567
# Epoch 8/100
# 28/28 [==============================] - 0s 14ms/step - loss: 4.1278e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0047 - val_mean_absolute_error: 0.0546
# Epoch 9/100
# 28/28 [==============================] - 0s 14ms/step - loss: 3.7613e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0390
# Epoch 10/100
# 28/28 [==============================] - 0s 14ms/step - loss: 3.6610e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0033 - val_mean_absolute_error: 0.0444
# Epoch 11/100
# 28/28 [==============================] - 0s 15ms/step - loss: 3.5671e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0055 - val_mean_absolute_error: 0.0604
# Epoch 12/100
# 28/28 [==============================] - 0s 14ms/step - loss: 3.4116e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0038 - val_mean_absolute_error: 0.0485
# Epoch 13/100
# 28/28 [==============================] - 0s 13ms/step - loss: 3.5371e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0046 - val_mean_absolute_error: 0.0545
# Epoch 14/100
# 28/28 [==============================] - 0s 11ms/step - loss: 3.3577e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0051 - val_mean_absolute_error: 0.0576
# Epoch 15/100
# 28/28 [==============================] - 0s 9ms/step - loss: 3.2745e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0057 - val_mean_absolute_error: 0.0615
# Epoch 16/100
# 28/28 [==============================] - 0s 11ms/step - loss: 3.2992e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0036 - val_mean_absolute_error: 0.0465
# Epoch 17/100
# 28/28 [==============================] - 0s 10ms/step - loss: 3.3663e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0034 - val_mean_absolute_error: 0.0443
# Epoch 18/100
# 28/28 [==============================] - 0s 10ms/step - loss: 3.2368e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0065 - val_mean_absolute_error: 0.0643
# Epoch 19/100
# 28/28 [==============================] - 0s 9ms/step - loss: 3.0456e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0051 - val_mean_absolute_error: 0.0566
# Epoch 20/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.7983e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0070 - val_mean_absolute_error: 0.0671
# Epoch 21/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.8202e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0043 - val_mean_absolute_error: 0.0501
# Epoch 22/100
# 28/28 [==============================] - 0s 10ms/step - loss: 3.1003e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0035 - val_mean_absolute_error: 0.0441
# Epoch 23/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.8641e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0037 - val_mean_absolute_error: 0.0454
# Epoch 24/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.7095e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0055 - val_mean_absolute_error: 0.0580
# Epoch 25/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.7635e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0064 - val_mean_absolute_error: 0.0630
# Epoch 26/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.7361e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 27/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.8485e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0061 - val_mean_absolute_error: 0.0630
# Epoch 28/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.5440e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0054 - val_mean_absolute_error: 0.0581
# Epoch 29/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.7256e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0032 - val_mean_absolute_error: 0.0415
# Epoch 30/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.6755e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0043 - val_mean_absolute_error: 0.0509
# Epoch 31/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.8744e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0043 - val_mean_absolute_error: 0.0512
# Epoch 32/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.5822e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0044 - val_mean_absolute_error: 0.0524
# Epoch 33/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.3306e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0025 - val_mean_absolute_error: 0.0369
# Epoch 34/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.4277e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0027 - val_mean_absolute_error: 0.0384
# Epoch 35/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.3637e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0033 - val_mean_absolute_error: 0.0434
# Epoch 36/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.3605e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0043 - val_mean_absolute_error: 0.0520
# Epoch 37/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.2941e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 38/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.3125e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0044 - val_mean_absolute_error: 0.0518
# Epoch 39/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.1441e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0058 - val_mean_absolute_error: 0.0608
# Epoch 40/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.2566e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0034 - val_mean_absolute_error: 0.0448
# Epoch 41/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.3983e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0070 - val_mean_absolute_error: 0.0702
# Epoch 42/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.3241e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0027 - val_mean_absolute_error: 0.0385
# Epoch 43/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.2516e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0033 - val_mean_absolute_error: 0.0438
# Epoch 44/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.1488e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 45/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.0187e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0043 - val_mean_absolute_error: 0.0518
# Epoch 46/100
# 28/28 [==============================] - 0s 9ms/step - loss: 2.1655e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0036 - val_mean_absolute_error: 0.0469
# Epoch 47/100
# 28/28 [==============================] - 0s 11ms/step - loss: 2.0850e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 48/100
# 28/28 [==============================] - 0s 14ms/step - loss: 2.0371e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0040 - val_mean_absolute_error: 0.0512
# Epoch 49/100
# 28/28 [==============================] - 1s 20ms/step - loss: 2.2269e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0016 - val_mean_absolute_error: 0.0301
# Epoch 50/100
# 28/28 [==============================] - 0s 13ms/step - loss: 2.1077e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0027 - val_mean_absolute_error: 0.0394
# Epoch 51/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.9191e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0023 - val_mean_absolute_error: 0.0366
# Epoch 52/100
# 28/28 [==============================] - 0s 14ms/step - loss: 2.0323e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0021 - val_mean_absolute_error: 0.0340
# Epoch 53/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.9956e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 54/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.7502e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0021 - val_mean_absolute_error: 0.0349
# Epoch 55/100
# 28/28 [==============================] - 0s 15ms/step - loss: 1.8855e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0014 - val_mean_absolute_error: 0.0275
# Epoch 56/100
# 28/28 [==============================] - 0s 14ms/step - loss: 2.0915e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0026 - val_mean_absolute_error: 0.0389
# Epoch 57/100
# 28/28 [==============================] - 0s 13ms/step - loss: 1.6801e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0028 - val_mean_absolute_error: 0.0405
# Epoch 58/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.7652e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 59/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.8660e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0014 - val_mean_absolute_error: 0.0274
# Epoch 60/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.6028e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0018 - val_mean_absolute_error: 0.0316
# Epoch 61/100
# 28/28 [==============================] - 0s 9ms/step - loss: 1.8307e-04 - mean_absolute_error: 0.0099 - val_loss: 9.6186e-04 - val_mean_absolute_error: 0.0228
# Epoch 62/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.7503e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 63/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.9698e-04 - mean_absolute_error: 0.0104 - val_loss: 6.3770e-04 - val_mean_absolute_error: 0.0196
# Epoch 64/100
# 28/28 [==============================] - 0s 10ms/step - loss: 2.0342e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0016 - val_mean_absolute_error: 0.0310
# Epoch 65/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.6823e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0026 - val_mean_absolute_error: 0.0414
# Epoch 66/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.7462e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0022 - val_mean_absolute_error: 0.0371
# Epoch 67/100
# 28/28 [==============================] - 0s 9ms/step - loss: 1.5415e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0015 - val_mean_absolute_error: 0.0286
# Epoch 68/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.5946e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 69/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.6872e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0016 - val_mean_absolute_error: 0.0308
# Epoch 70/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.6400e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 71/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.5085e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0036 - val_mean_absolute_error: 0.0502
# Epoch 72/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.6056e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 73/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.4685e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 74/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309
# Epoch 75/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.4499e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0029 - val_mean_absolute_error: 0.0441
# Epoch 76/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.6062e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0032 - val_mean_absolute_error: 0.0469
# Epoch 77/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.4818e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0024 - val_mean_absolute_error: 0.0387
# Epoch 78/100
# 28/28 [==============================] - 0s 9ms/step - loss: 1.4637e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 79/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.4750e-04 - mean_absolute_error: 0.0090 - val_loss: 6.3531e-04 - val_mean_absolute_error: 0.0187
# Epoch 80/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.3609e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 81/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.3104e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0015 - val_mean_absolute_error: 0.0302
# Epoch 82/100
# 28/28 [==============================] - 0s 17ms/step - loss: 1.3800e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 83/100
# 28/28 [==============================] - 1s 18ms/step - loss: 1.3325e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0363
# Epoch 84/100
# 28/28 [==============================] - 1s 20ms/step - loss: 1.3456e-04 - mean_absolute_error: 0.0084 - val_loss: 8.9220e-04 - val_mean_absolute_error: 0.0224
# Epoch 85/100
# 28/28 [==============================] - 1s 21ms/step - loss: 1.3081e-04 - mean_absolute_error: 0.0084 - val_loss: 9.5089e-04 - val_mean_absolute_error: 0.0229
# Epoch 86/100
# 28/28 [==============================] - 1s 18ms/step - loss: 1.3761e-04 - mean_absolute_error: 0.0084 - val_loss: 9.8056e-04 - val_mean_absolute_error: 0.0236
# Epoch 87/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.2302e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 88/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2681e-04 - mean_absolute_error: 0.0080 - val_loss: 5.8518e-04 - val_mean_absolute_error: 0.0178
# Epoch 89/100
# 28/28 [==============================] - 0s 15ms/step - loss: 1.2443e-04 - mean_absolute_error: 0.0080 - val_loss: 6.6000e-04 - val_mean_absolute_error: 0.0191
# Epoch 90/100
# 28/28 [==============================] - 0s 15ms/step - loss: 1.2128e-04 - mean_absolute_error: 0.0079 - val_loss: 9.6740e-04 - val_mean_absolute_error: 0.0239
# Epoch 91/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.2296e-04 - mean_absolute_error: 0.0078 - val_loss: 4.9261e-04 - val_mean_absolute_error: 0.0165
# Epoch 92/100
# 28/28 [==============================] - 0s 13ms/step - loss: 1.5155e-04 - mean_absolute_error: 0.0090 - val_loss: 3.5966e-04 - val_mean_absolute_error: 0.0142
# Epoch 93/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.2319e-04 - mean_absolute_error: 0.0079 - val_loss: 5.4869e-04 - val_mean_absolute_error: 0.0174
# Epoch 94/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.2775e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 95/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.3285e-04 - mean_absolute_error: 0.0082 - val_loss: 6.3337e-04 - val_mean_absolute_error: 0.0192
# Epoch 96/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1443e-04 - mean_absolute_error: 0.0076 - val_loss: 7.9039e-04 - val_mean_absolute_error: 0.0215
# Epoch 97/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1344e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 98/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1931e-04 - mean_absolute_error: 0.0078 - val_loss: 4.5126e-04 - val_mean_absolute_error: 0.0160
# Epoch 99/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.1604e-04 - mean_absolute_error: 0.0075 - val_loss: 7.4260e-04 - val_mean_absolute_error: 0.0213
# Epoch 100/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.0967e-04 - mean_absolute_error: 0.0074 - val_loss: 5.5462e-04 - val_mean_absolute_error: 0.0178

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 4ms/step
# array([[0.40591812, 0.40741318],
#        [0.40480584, 0.40644565],
#        [0.3991425 , 0.40089893],
#        [0.4027174 , 0.4043907 ],
#        [0.40645856, 0.40802392]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1423.5397, 1423.3352],
#        [1421.4777, 1421.542 ],
#        [1410.9783, 1411.2621],
#        [1417.6058, 1417.7335],
#        [1424.5416, 1424.467 ]], dtype=float32)

# %% [markdown]
# ##STEP 5 : VISUALIZING ACTUAL Data VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1423.539673      1423.335205
# 2020-05-28  1396.86  1416.73     1421.477661      1421.541992
# 2020-05-29  1416.94  1428.92     1410.978271      1411.262085
# 2020-06-01  1418.39  1431.82     1417.605835      1417.733521
# 2020-06-02  1430.55  1439.22     1424.541626      1424.467041

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ##STEP 6. PREDICTING UPCOMING 15 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2431.855225      2439.776855
# 2021-06-10  2494.01  2521.60     2438.106934      2447.682861
# 2021-06-11  2524.92  2513.93     2444.970215      2455.093018
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
# Inversing Normalization/scaling

upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# Plotting Upcoming Open price on date index

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open Price Prediction',size=15)
ax.legend()
fig.show()

# %%
# Plotting Upcoming Close price on date index

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Close Price Prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# #What can be inferred form the above analysis.
